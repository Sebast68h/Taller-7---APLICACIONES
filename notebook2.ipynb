# %%
import pandas as pd

# %%
df = pd.read_excel("movies.xlsx")
df
# Out:
#                                                 MOVIES               YEAR  \
# 0                     PokÃ©mon: Happy Birthday to You!  (2017 TV Special)
# 1                    Beat Bugs: Happy Birthday to You!  (2017 TV Special)
# 2                 Project McÂ²: Happy Birthday to You!  (2017 TV Special)
# 3                                The Sense8 Experience             (2017)
# 4    Night of 1000 Meryls: Drag Queens Perform Mery...       (2020 Video)
# ..                                                 ...                ...
# 995                                       The 39 Steps                NaN
# 996                                       On the Verge         (2021â€“ )
# 997                                            Toy Boy             (2019)
# 998                                          Connected                NaN
# 999                                   Tribes of Europa         (2021â€“ )
#
#                                       GENRE  RATING  \
# ...
